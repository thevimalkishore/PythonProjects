# %%
print("SMS Automation")
# Out:
# SMS Automation

# %%
from twilio.rest import Client
ACCOUNT_SID="Ac2b7a3fec0554f1d681b1613c1c6bea8e"
AUTH_TOKEN= "YYYYYYYYYYYYYYYYYYY" #khud ka token enter krna from twilio
TWILIO_NUMBER= "+18103214740"
RECIVER_NUMBER= "+17854537903"
Client = Client(ACCOUNT_SID,AUTH_TOKEN)
message = Client.messages.create(
    body="Hello i am vimal ", 
    from_ = TWILIO_NUMBER, 
    to=RECEIVER_NUMBER
)
