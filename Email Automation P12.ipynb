# %%
print("Email Automation")
# Out:
# Email Automation

# %%
import smtplib
import ssl
from email.message import EmailMessage
EMAIL = Abc@gmail.com
APP_PASSWORD = "XXXXXXXXXX"
RECEIVER = "xyz@gmail.com"
msg = EmailMessage()
msg["From"] = EMAIL
msg["To"] = RECEIVER
msg["Subject"] = "Hello FOR PYTHON ......"
msg.set_content("This email was shared by python code ......")
context = ssl.create_default_context()
with smtplip.SMPT_SSL("smtp.gmail.com",465 ,context=context) as server:
    server.login(EMAIL, APP_PASSWORD)
    server.send_message(msg)
